# %% [markdown]
# # 1908-powershell-format-list-all

# %% [markdown]
# ## reference

# %% [markdown]
# - Using Format Commands to Change Output View
#   - https://docs.microsoft.com/ja-jp/powershell/scripting/samples/using-format-commands-to-change-output-view?view=powershell-6

# %% [markdown]
# ## log

# %%
Get-Process
# Out:
# Handles  NPM(K)    PM(K)      WS(K)     CPU(s)     Id  SI ProcessName
# -------  ------    -----      -----     ------     --  -- -----------
#     228      20     3876       9460              3728   0 AppleMobileDeviceService
#     518      30    20604      38700       2.72  21320   7 ApplicationFrameHost
#     157       8     1860       6360             15068   0 AppVShNotify
#     474      25     5536      17044       0.23   6632   7 APSDaemon
#     155       9     1396       5980              3720   0 armsvc
#    1106      46    18204      48476       0.52   7820   7 backgroundTaskHost
#     411      17     3684      16812       0.25  19748   7 browser_broker
#     213      13     2860      11852       0.16  13032   7 Charu3
#      46       5     2608       3420       0.02  11444   7 cmd
#      39       5     2612       3060       0.03  16756   7 cmd
#     197      14     3032      11372       0.91   1884   7 CNABISWD
# ...

# %%
Get-Process -Name powershell
# Out:
# Handles  NPM(K)    PM(K)      WS(K)     CPU(s)     Id  SI ProcessName
# -------  ------    -----      -----     ------     --  -- -----------
#     584      27    94388     103264       1.58   9948   7 powershell
#     509      27    60772      70752   1,503.72  10272   7 powershell
#     706      30    65776      79376       1.19  14052   7 powershell

# %%
Get-Process | where {$_.Id -eq 10272}
# Out:
# Handles  NPM(K)    PM(K)      WS(K)     CPU(s)     Id  SI ProcessName
# -------  ------    -----      -----     ------     --  -- -----------
#     509      27    61084      71084   1,543.41  10272   7 powershell

# %%
Get-Process | where {$_.Id -eq 10272} | Format-List -Property *
# Out:
# Name                       : powershell
# Id                         : 10272
# PriorityClass              : Normal
# FileVersion                : 10.0.17134.945 (WinBuild.160101.0800)
# HandleCount                : 509
# WorkingSet                 : 67465216
# PagedMemorySize            : 61800448
# PrivateMemorySize          : 61800448
# VirtualMemorySize          : 702685184
# TotalProcessorTime         : 00:26:32.3906250
# SI                         : 7
# Handles                    : 509
# VM                         : 2204020908032
# WS                         : 67465216
# PM                         : 61800448
# NPM                        : 27872
# Path                       : C:\WINDOWS\System32\WindowsPowerShell\v1.0\powershell.exe
# Company                    : Microsoft Corporation
# CPU                        : 1592.421875
# ProductVersion             : 10.0.17134.945
# Description                : Windows PowerShell
# ...

# %%
Get-Process | where {$_.Id -eq 10272} | Format-Table -Property *
# Out:
# Name          Id PriorityClass FileVersion                           HandleCount WorkingSet PagedMemorySize PrivateMemo
#                                                                                                                  rySize
# ----          -- ------------- -----------                           ----------- ---------- --------------- -----------
# powershell 10272        Normal 10.0.17134.945 (WinBuild.160101.0800)         509   67026944        62287872    62287872
